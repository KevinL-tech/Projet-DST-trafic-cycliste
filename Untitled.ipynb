# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import preprocessing
from sklearn import linear_model
from sklearn.model_selection import train_test_split
# %matplotlib inline
df = pd.read_csv("velo.csv", sep = ";")

# %%
df.shape
# Out:
# (946275, 16)

# %%
df.head()
# Out:
#   Identifiant du compteur                     Nom du compteur  \
# 0     100003098-101003098  106 avenue Denfert Rochereau NE-SO
# 1     100003098-101003098  106 avenue Denfert Rochereau NE-SO
# 2     100003098-101003098  106 avenue Denfert Rochereau NE-SO
# 3     100003098-101003098  106 avenue Denfert Rochereau NE-SO
# 4     100003098-101003098  106 avenue Denfert Rochereau NE-SO
#
#    Identifiant du site de comptage       Nom du site de comptage  \
# 0                      100003098.0  106 avenue Denfert Rochereau
# 1                      100003098.0  106 avenue Denfert Rochereau
# 2                      100003098.0  106 avenue Denfert Rochereau
# 3                      100003098.0  106 avenue Denfert Rochereau
# 4                      100003098.0  106 avenue Denfert Rochereau
#
#    Comptage horaire  Date et heure de comptage  \
# 0                36  2024-01-01T04:00:00+01:00
# 1                27  2024-01-01T05:00:00+01:00
# 2                10  2024-01-01T07:00:00+01:00
# 3                 4  2024-01-01T08:00:00+01:00
# 4                15  2024-01-01T06:00:00+01:00
#
#   Date d'installation du site de comptage  \
# 0                              2012-02-22
# 1                              2012-02-22
# 2                              2012-02-22
# 3                              2012-02-22
# 4                              2012-02-22
#
#                  Lien vers photo du site de comptage  \
# 0  https://filer.eco-counter-tools.com/file/09/73...
# 1  https://filer.eco-counter-tools.com/file/09/73...
# 2  https://filer.eco-counter-tools.com/file/09/73...
# 3  https://filer.eco-counter-tools.com/file/09/73...
# 4  https://filer.eco-counter-tools.com/file/09/73...
#
#   Coordonnées géographiques Identifiant technique compteur  \
# 0          48.83507,2.33305                    Y2H20114504
# 1          48.83507,2.33305                    Y2H20114504
# 2          48.83507,2.33305                    Y2H20114504
# 3          48.83507,2.33305                    Y2H20114504
# 4          48.83507,2.33305                    Y2H20114504
#
#                                            ID Photos  \
# 0  https://filer.eco-counter-tools.com/file/09/73...
# 1  https://filer.eco-counter-tools.com/file/09/73...
# 2  https://filer.eco-counter-tools.com/file/09/73...
# 3  https://filer.eco-counter-tools.com/file/09/73...
# 4  https://filer.eco-counter-tools.com/file/09/73...
#
#           test_lien_vers_photos_du_site_de_comptage_ id_photo_1  \
# 0  https://filer.eco-counter-tools.com/file/09/73...     https:
# 1  https://filer.eco-counter-tools.com/file/09/73...     https:
# 2  https://filer.eco-counter-tools.com/file/09/73...     https:
# 3  https://filer.eco-counter-tools.com/file/09/73...     https:
# 4  https://filer.eco-counter-tools.com/file/09/73...     https:
#
#                                     url_sites type_dimage mois_annee_comptage
# 0  https://www.eco-visio.net/Photos/100003098         jpg             2024-01
# 1  https://www.eco-visio.net/Photos/100003098         jpg             2024-01
# 2  https://www.eco-visio.net/Photos/100003098         jpg             2024-01
# 3  https://www.eco-visio.net/Photos/100003098         jpg             2024-01
# 4  https://www.eco-visio.net/Photos/100003098         jpg             2024-01

# %%
df["Comptage horaire"].value_counts()
# Out:
# Comptage horaire
# 0       50610
# 1       25450
# 2       24674
# 3       22673
# 4       20639
#         ...
# 1055        1
# 1258        1
# 1133        1
# 1311        1
# 978         1
# Name: count, Length: 1251, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 946275 entries, 0 to 946274
# Data columns (total 16 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   Identifiant du compteur                     884670 non-null  object
#  1   Nom du compteur                             946275 non-null  object
#  2   Identifiant du site de comptage             884670 non-null  float64
#  3   Nom du site de comptage                     884670 non-null  object
#  4   Comptage horaire                            946275 non-null  int64
#  5   Date et heure de comptage                   946275 non-null  object
#  6   Date d'installation du site de comptage     884670 non-null  object
#  7   Lien vers photo du site de comptage         874859 non-null  object
#  8   Coordonnées géographiques                   884670 non-null  object
#  9   Identifiant technique compteur              874857 non-null  object
#  10  ID Photos                                   874859 non-null  object
#  11  test_lien_vers_photos_du_site_de_comptage_  874859 non-null  object
#  12  id_photo_1                                  874859 non-null  object
#  13  url_sites                                   884670 non-null  object
#  14  type_dimage                                 874859 non-null  object
#  15  mois_annee_comptage                         946275 non-null  object
# dtypes: float64(1), int64(1), object(14)
# memory usage: 115.5+ MB

# %%
# Convertir la colonne en datetime (avec gestion du fuseau horaire)
df["Date et heure de comptage"] = pd.to_datetime(df["Date et heure de comptage"], utc=True)

# %%
df.dtypes
# Out:
# Identifiant du compteur                                    object
# Nom du compteur                                            object
# Identifiant du site de comptage                           float64
# Nom du site de comptage                                    object
# Comptage horaire                                            int64
# Date et heure de comptage                     datetime64[ns, UTC]
# Date d'installation du site de comptage                    object
# Lien vers photo du site de comptage                        object
# Coordonnées géographiques                                  object
# Identifiant technique compteur                             object
# ID Photos                                                  object
# test_lien_vers_photos_du_site_de_comptage_                 object
# id_photo_1                                                 object
# url_sites                                                  object
# type_dimage                                                object
# mois_annee_comptage                                        object
# dtype: object

# %%
#Met les dates dans l'ordre croissant
df = df.sort_values(by="Date et heure de comptage")

# %%
#Crée 3 colonnes Année, Jour et Heure (Mois existe déjà) en mettant
#l'année à la 15eme colonne pour faire Année Mois Jour Heure dans le dataframe

df.insert(15, "Année", df["Date et heure de comptage"].dt.year)
df["Jour"] = df["Date et heure de comptage"].dt.date
df["Heure"] = df["Date et heure de comptage"].dt.hour

# %%
plt.figure(figsize=(12, 6))
plt.plot(df["Date et heure de comptage"], df["Comptage horaire"], marker = "o", linestyle = "-", alpha = 0.5)
plt.xlabel("Date et Heure")
plt.ylabel("Nombre de vélos")
plt.title("Évolution du comptage des vélos en fonction du temps")
plt.xticks(rotation=45)
plt.grid()

# Afficher le graphique
plt.show()

# %%
comptage_annuel = df.groupby("Année")["Comptage horaire"].sum()
comptage_mensuel = df.groupby("mois_annee_comptage")["Comptage horaire"].sum()
comptage_quotidien = df.groupby("Jour")["Comptage horaire"].sum()
comptage_horaire = df.groupby("Heure")["Comptage horaire"].sum()

# %%
print(comptage_annuel)
print("Au total, toutes années confondues, on a relevé",(comptage_annuel).sum(), "cyclistes dans la capitale.")
# Out:
# Année
# 2022           5
# 2024    64644553
# 2025     6316665
# Name: Comptage horaire, dtype: int64
# Au total, toutes années confondues, on a relevé 70961223 cyclistes dans la capitale.

# %%
print(comptage_mensuel)
# Out:
# mois_annee_comptage
# 2022-03          0
# 2022-04          0
# 2022-06          0
# 2022-08          5
# 2024-01    4286746
# 2024-02    4541407
# 2024-03    5480416
# 2024-04    5386934
# 2024-05    5760008
# 2024-06    6515408
# 2024-07    5807252
# 2024-08    4762143
# 2024-09    6459335
# 2024-10    6098886
# 2024-11    5268346
# 2024-12    4275708
# 2025-01    4402441
# 2025-02    1916188
# Name: Comptage horaire, dtype: int64

# %%
print(comptage_quotidien)
print(''' 
On peut se rendre compte ici que l'année 2022 ne nous apporte pas vraiment d'éléments
significatifs à traiter, on pourra donc la supprimer de notre dataset.''')
# Out:
# Jour
# 2022-03-27         0
# 2022-04-05         0
# 2022-06-23         0
# 2022-08-03         5
# 2024-01-01     52518
#                ...
# 2025-02-08    127304
# 2025-02-09    102829
# 2025-02-10    146681
# 2025-02-11    198402
# 2025-02-12    188906
# Name: Comptage horaire, Length: 413, dtype: int64
#
# On peut se rendre compte ici que l'année 2022 ne nous apporte pas vraiment d'éléments
# significatifs à traiter, on pourra donc la supprimer de notre dataset.

# %%
print(comptage_horaire)
# Out:
# Heure
# 0      583214
# 1      375753
# 2      244643
# 3      269788
# 4      466186
# 5     1287365
# 6     4055942
# 7     5935985
# 8     4255941
# 9     2816812
# 10    3170122
# 11    3514652
# 12    3452441
# 13    3447513
# 14    3699913
# 15    4721609
# 16    6427390
# 17    6893184
# 18    5207168
# 19    3188320
# 20    2373584
# 21    2115583
# 22    1540171
# 23     917944
# Name: Comptage horaire, dtype: int64

# %%
# Pour suprimer les lignes se référant à l'année 2022 :
df = df.drop(df[df["Date et heure de comptage"].dt.year == 2022].index)

# %%
# Compter le nombre de NaN/NaT dans chaque colonne
nan_counts = df.isna().sum()

print(nan_counts)
# Out:
# Identifiant du compteur                       61605
# Nom du compteur                                   0
# Identifiant du site de comptage               61605
# Nom du site de comptage                       61605
# Comptage horaire                                  0
# Date et heure de comptage                         0
# Date d'installation du site de comptage       61605
# Lien vers photo du site de comptage           71416
# Coordonnées géographiques                     61605
# Identifiant technique compteur                71418
# ID Photos                                     71416
# test_lien_vers_photos_du_site_de_comptage_    71416
# id_photo_1                                    71416
# url_sites                                     61605
# type_dimage                                   71416
# Année                                             0
# mois_annee_comptage                               0
# Jour                                              0
# Heure                                             0
# dtype: int64

# %%
#Graphique représentant l'évolution du nombre de cycliste dans la capitale suivant l'année.

plt.figure(figsize=(8, 4))
plt.bar(comptage_annuel.index, comptage_annuel.values, color = "blue")
plt.xlabel("Année")
plt.ylabel("Nombre de vélos")
plt.title("Comptage annuel des vélos")
plt.grid(axis = "y", linestyle = "--", alpha = 0.7)
plt.show()

print('''
Nous constatons ici que l'année 2024 a rassemblé au total environ 65 millions de cyclistes.''')
# Out:
# Nous constatons ici que l'année 2024 a rassemblé au total environ 65 millions de cyclistes.

# %%
plt.figure(figsize=(12, 5))
plt.plot(comptage_quotidien.index.astype(str), comptage_quotidien.values, linestyle = "-", color = "orange")

plt.xlabel("Jour")
plt.ylabel("Nombre de vélos")
plt.title("Évolution du comptage quotidien des vélos")
plt.xticks(ticks = range(0, len(comptage_quotidien), 15), labels = comptage_quotidien.index[::15].astype(str), rotation = 45, fontsize = 8)

plt.grid(axis = "y", linestyle = "--", alpha = 0.7)
plt.show() 

print(''' 
On peut observer ici certaines tendances notamment des diminutions significatives
au mois d'Août et Décembre qui correspondent respectivement à une saison chaude
pendant les vacances scolaires (voyages, etc.) et à Noël (saison plus froide et familiale).
Il semble également y avoir une reprise au mois de Septembre montrant la reprise du travail 
et la rentrée pour les étudiants.''')
# Out:
#
# On peut observer ici certaines tendances notamment des diminutions significatives
# au mois d'Août et Décembre qui correspondent respectivement à une saison chaude
# pendant les vacances scolaires (voyages, etc.) et à Noël (saison plus froide et familiale).
# Il semble également y avoir une reprise au mois de Septembre montrant la reprise du travail
# et la rentrée pour les étudiants.

# %%
plt.figure(figsize=(10, 5))
plt.bar(comptage_horaire.index, comptage_horaire.values, color = "blue")
plt.xticks(range(0,24))
plt.xlabel("Heure")
plt.ylabel("Nombre de vélos")
plt.title("Comptage horaire des vélos")
plt.grid(axis = "y", linestyle = "--", alpha = 0.7)
plt.show()

print('''
Nous pouvons constater ici que les heures les plus fréquentées sont celles de 7h et 17h
ce qui correspond plus ou moins aux horaires de travail et celles des étudiants.''')
# Out:
# Nous pouvons constater ici que les heures les plus fréquentées sont celles de 7h et 17h
# ce qui correspond plus ou moins aux horaires de travail et celles des étudiants.

# %%
df.dtypes
# Out:
# Identifiant du compteur                                    object
# Nom du compteur                                            object
# Identifiant du site de comptage                           float64
# Nom du site de comptage                                    object
# Comptage horaire                                            int64
# Date et heure de comptage                     datetime64[ns, UTC]
# Date d'installation du site de comptage                    object
# Lien vers photo du site de comptage                        object
# Coordonnées géographiques                                  object
# Identifiant technique compteur                             object
# ID Photos                                                  object
# test_lien_vers_photos_du_site_de_comptage_                 object
# id_photo_1                                                 object
# url_sites                                                  object
# type_dimage                                                object
# Année                                                       int32
# mois_annee_comptage                                        object
# Jour                                                       object
# Heure                                                       int32
# dtype: object

# %%
comptage_site_de_comptage = df.groupby("Nom du site de comptage")["Comptage horaire"].sum()

# %%
print(comptage_site_de_comptage)
# Out:
# Nom du site de comptage
# 10 avenue de la Grande Armée          27995
# 10 boulevard Auguste Blanqui         422387
# 100 rue La Fayette                        0
# 102 boulevard de Magenta            2144732
# 106 avenue Denfert Rochereau           9007
#                                      ...
# Totem 64 Rue de Rivoli              4061334
# Totem 73 boulevard de Sébastopol    5376210
# Totem 85 quai d'Austerlitz          1980255
# Totem Cours la Reine                 658407
# Voie Georges Pompidou               1132541
# Name: Comptage horaire, Length: 68, dtype: int64

# %%
plt.figure(figsize=(12, 6))

# Création du boxplot
df.boxplot(column = "Comptage horaire", by = "Nom du site de comptage", vert = False, patch_artist = True)

plt.xlabel("Nombre de vélos")
plt.ylabel("Site de comptage")
plt.title("Distribution des comptages par site (Boxplot)")
plt.suptitle("")  # Enlève le titre par défaut de Pandas

plt.grid(axis = "x", linestyle = "--", alpha = 0.7)
plt.show()

# %%
site_groups = np.array_split(df["Nom du site de comptage"].unique(), 3)

# %%
for i, group in enumerate(site_groups):
    df_subset = df[df["Nom du site de comptage"].isin(group)]
    
    plt.figure(figsize=(12, 6))
    df_subset.boxplot(column="Comptage horaire", by="Nom du site de comptage", vert=False, patch_artist=True)
    
    plt.xlabel("Nombre de vélos")
    plt.ylabel("Site de comptage")
    plt.title(f"Distribution des comptages (Groupe {i+1})")
    plt.suptitle("")  # Enlever le titre par défaut
    
    plt.grid(axis = "x", linestyle = "--", alpha = 0.7)
    plt.show()

print('''
Ces graphiques sont triés des stations les plus fréquentées (groupe 1) aux moins fréquentées (groupe 3).
On peut se rendre compte que beaucoup de stations tendent vers 0 ce qui pourraient montrer un disfonctionnement des compteurs.
Par ailleurs, on remarque des valeurs aberrantes comme environ 1600 au Totem 64 Rue de Rivoli ou un peu plus de 3000 au Quai d'Orsay.
Au Quai d'Orsay, il s'agissait du Dimanche 05 Janvier à 14h avec une météo peu clémente, il n'y a pas vraiment d'explication à ce chiffre élevé.''')
# Out:
# Ces graphiques sont triés des stations les plus fréquentées (groupe 1) aux moins fréquentées (groupe 3).
# On peut se rendre compte que beaucoup de stations tendent vers 0 ce qui pourraient montrer un disfonctionnement des compteurs.
# Par ailleurs, on remarque des valeurs aberrantes comme environ 1600 au Totem 64 Rue de Rivoli ou un peu plus de 3000 au Quai d'Orsay.
# Au Quai d'Orsay, il s'agissait du Dimanche 05 Janvier à 14h avec une météo peu clémente, il n'y a pas vraiment d'explication à ce chiffre élevé.

# %%
jour_3000 = df[df["Comptage horaire"] > 3000]

# %%
print(jour_3000)
# Out:
#        Identifiant du compteur   Nom du compteur  \
# 690324     100056335-103056335  Quai d'Orsay O-E
#
#         Identifiant du site de comptage Nom du site de comptage  \
# 690324                      100056335.0            Quai d'Orsay
#
#         Comptage horaire Date et heure de comptage  \
# 690324              3070 2025-01-05 14:00:00+00:00
#
#        Date d'installation du site de comptage  \
# 690324                              2019-11-07
#
#                       Lien vers photo du site de comptage  \
# 690324  https://filer.eco-counter-tools.com/file/14/a8...
#
#        Coordonnées géographiques Identifiant technique compteur  \
# 690324            48.8629,2.3118                    Y2H19070382
#
#                                                 ID Photos  \
# 690324  https://filer.eco-counter-tools.com/file/14/a8...
#
#                test_lien_vers_photos_du_site_de_comptage_ id_photo_1  \
# 690324  https://filer.eco-counter-tools.com/file/14/a8...     https:
#
#                                          url_sites type_dimage  Année  \
# 690324  https://www.eco-visio.net/Photos/100056335         jpg   2025
#
#        mois_annee_comptage        Jour  Heure
# 690324             2025-01  2025-01-05     14

# %%
df_backup = df.copy()

# %%
stations_zero = df[df["Comptage horaire"] == 0]["Nom du site de comptage"].unique()

# %%
print(stations_zero)
# Out:
# ['21 boulevard Saint Michel' "Face au 25 quai de l'Oise"
#  '100 rue La Fayette' 'Face au 16 avenue de la  Porte des Ternes' nan
#  "Face au 40 quai D'Issy" 'Voie Georges Pompidou'
#  '21 boulevard Auguste Blanqui'
#  'Face au 8 avenue de la porte de Charenton'
#  '33 avenue des Champs Elysées' 'Pont Charles De Gaulle'
#  '81 boulevard Mortier' '51 boulevard du Général Martial Valin'
#  '7 avenue de la Grande Armée' "Face 104 rue d'Aubervilliers"
#  'Face au 4 avenue de la porte de Bagnolet' 'Pont des Invalides'
#  'Face au 70 quai de Bercy' '135 avenue Daumesnil'
#  '39 quai François Mauriac' '27 boulevard Davout'
#  '16 avenue de la Porte des Ternes' '129 rue Lecourbe'
#  '24 boulevard Jourdan' '56 boulevard Kellermann'
#  "Totem 85 quai d'Austerlitz" '38 rue Turbigo'
#  '152 boulevard du Montparnasse' '72 boulevard Brune'
#  '87 avenue de Flandre' 'Pont de Bercy' "147 avenue d'Italie"
#  'Pont National' "18 quai de l'Hôtel de Ville" '9 boulevard Jourdan'
#  'Totem Cours la Reine' '98 boulevard Poniatowski' '28 boulevard Diderot'
#  '67 boulevard Voltaire' '10 boulevard Auguste Blanqui'
#  '77 boulevard Masséna' 'Pont de la Concorde' '6 rue Julia Bartet'
#  '106 avenue Denfert Rochereau' '36 quai de Grenelle'
#  'Face au 49 boulevard du Général Martial Valin' 'Pont du Garigliano'
#  '163 boulevard Brune' '72 boulevard Richard Lenoir' "Quai d'Orsay"
#  '42 boulevard Soult' '27 boulevard Diderot' '132 rue Lecourbe'
#  'Totem 64 Rue de Rivoli' '77 boulevard Richard Lenoir'
#  "180 avenue d'Italie" '243 boulevard Saint Germain'
#  '35 boulevard de Ménilmontant' 'Totem 73 boulevard de Sébastopol'
#  '44 avenue des Champs Elysées' 'Pont des Invalides (couloir bus)'
#  '27 quai de la Tournelle' 'Quai des Tuileries'
#  'Face au 48 quai de la marne' '10 avenue de la Grande Armée']

# %%
df_2024 = df[df["Année"]==2024]

# %%
df_2024.loc[:, "Date et heure de comptage"] = df_2024["Date et heure de comptage"].dt.tz_localize(None)

# %%
# Regrouper par mois et sommer les comptages horaires
comptage_mensuel_2024 = df_2024.groupby(df_2024["Date et heure de comptage"].dt.to_period("M"))["Comptage horaire"].sum()

# %%
plt.figure(figsize=(10, 5))
comptage_mensuel_2024.plot(kind="line", marker="o", color="blue")

plt.xlabel("Mois")
plt.ylabel("Nombre de vélos")
plt.title("Évolution de l'utilisation des vélos par mois en 2024")
plt.grid(axis = "y", linestyle = "--", alpha = 0.7)
plt.xticks(rotation=45)  # Rotation des labels pour lisibilité

plt.show()

# %%
nombre_station_unique = df["Nom du site de comptage"].nunique()

# %%
print(nombre_station_unique)
# Out:
# 68

# %%
type_image = df["type_dimage"].nunique()

# %%
print(type_image)
# Out:
# 1

# %%
id_photo_1 = df["id_photo_1"].nunique()

# %%
print(id_photo_1)
# Out:
# 1

# %%
perc_val_manq = df.isna().mean()*100
total_perc_val_manq = (df.isna().mean()*100).sum()
print(perc_val_manq)
print("\n", total_perc_val_manq, "%.")
# Out:
# Identifiant du compteur                       6.510264
# Nom du compteur                               0.000000
# Identifiant du site de comptage               6.510264
# Nom du site de comptage                       6.510264
# Comptage horaire                              0.000000
# Date et heure de comptage                     0.000000
# Date d'installation du site de comptage       6.510264
# Lien vers photo du site de comptage           7.547066
# Coordonnées géographiques                     6.510264
# Identifiant technique compteur                7.547277
# ID Photos                                     7.547066
# test_lien_vers_photos_du_site_de_comptage_    7.547066
# id_photo_1                                    7.547066
# url_sites                                     6.510264
# type_dimage                                   7.547066
# Année                                         0.000000
# mois_annee_comptage                           0.000000
# Jour                                          0.000000
# Heure                                         0.000000
# dtype: float64
#
#  84.34419169903042 %.

# %%
###Colonnes à supprimer potentiellement : 
# • Lien vers photo du site de comptage
# • Identifiant technique compteur
# • ID Photos
# • test_lien_vers_photos_du_site_de_comptage
# • id_photo_1
# • url_sites
# • type_dimage
